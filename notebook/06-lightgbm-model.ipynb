# %% [markdown]
# ### Испытание модели LightGBM
#
# Эксперименты с CatBoost показали, что без тонкой настройки он чувствителен к размеру данных. Даже на 15% строк обучение растягивается на 20 минут. Идея сокращать датасет мне изначально не очень близка. Поэтому попробуем все же проглотить всего этого слона при помощи LightGBM.

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score #, mean_squared_error
import lightgbm as lgb
import pandas as pd
import os
os.chdir("D:/demo/ML/demo_dominicks")

from src.utils import prepare_training_data

baseline_df = pd.read_csv('data/baseline_dataset.csv', index_col=0)
baseline_df.head()
# Out:
#    com_code         upc               descrip   size  store  week  move  \
# 0       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   306     0
# 1       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   307     1
# 2       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   308     0
# 3       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   309     0
# 4       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   310     0
#
#    price sale     age60  ...      educ    ethnic     income   hhlarge  \
# 0   0.00    N  0.149192  ...  0.087712  0.425324  10.140613  0.144374
# 1   2.99    N  0.149192  ...  0.087712  0.425324  10.140613  0.144374
# 2   0.00    N  0.149192  ...  0.087712  0.425324  10.140613  0.144374
# 3   0.00    N  0.149192  ...  0.087712  0.425324  10.140613  0.144374
# 4   0.00    N  0.149192  ...  0.087712  0.425324  10.140613  0.144374
#
#     workwom  hval150  sstrdist   sstrvol   cpdist5   cpwvol5
# 0  0.296353  0.09633   3.55838  0.909091  1.075632  0.214417
# 1  0.296353  0.09633   3.55838  0.909091  1.075632  0.214417
# 2  0.296353  0.09633   3.55838  0.909091  1.075632  0.214417
# 3  0.296353  0.09633   3.55838  0.909091  1.075632  0.214417
# 4  0.296353  0.09633   3.55838  0.909091  1.075632  0.214417
#
# [5 rows x 21 columns]

# %%
baseline_df.loc[:, 'size_cat'] = baseline_df['size'].astype('category').cat.codes.astype(int)
baseline_df.loc[:, 'descrip_cat'] = baseline_df['descrip'].astype('category').cat.codes.astype(int)
baseline_df.loc[:, 'sale_cat'] = baseline_df['sale'].astype('category').cat.codes.astype(int)
#test_df['pack'].cat.codes
baseline_df.head(5)
# Out:
#    com_code         upc               descrip   size  store  week  move  \
# 0       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   306     0
# 1       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   307     1
# 2       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   308     0
# 3       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   309     0
# 4       953  1192603016  CAFFEDRINE CAPLETS 1  16 CT     76   310     0
#
#    price sale     age60  ...   hhlarge   workwom  hval150  sstrdist   sstrvol  \
# 0   0.00    N  0.149192  ...  0.144374  0.296353  0.09633   3.55838  0.909091
# 1   2.99    N  0.149192  ...  0.144374  0.296353  0.09633   3.55838  0.909091
# 2   0.00    N  0.149192  ...  0.144374  0.296353  0.09633   3.55838  0.909091
# 3   0.00    N  0.149192  ...  0.144374  0.296353  0.09633   3.55838  0.909091
# 4   0.00    N  0.149192  ...  0.144374  0.296353  0.09633   3.55838  0.909091
#
#     cpdist5   cpwvol5  size_cat  descrip_cat  sale_cat
# 0  1.075632  0.214417        19          120         3
# 1  1.075632  0.214417        19          120         3
# 2  1.075632  0.214417        19          120         3
# 3  1.075632  0.214417        19          120         3
# 4  1.075632  0.214417        19          120         3
#
# [5 rows x 24 columns]

# %%
X_train, X_test, y_train, y_test = prepare_training_data(baseline_df, 
                cat_cols=['descrip_cat', 'size_cat', 'sale_cat'],
                cols2drop=['com_code', 'upc', 'store', 'size', 'descrip', 'sale'],
                target_cols=['move'])
# Out:
# cat_features : 3 ['descrip_cat', 'size_cat', 'sale_cat']
# num_features : 14 ['week', 'price', 'age60', 'age9', 'educ', 'ethnic', 'income', 'hhlarge', 'workwom', 'hval150', 'sstrdist', 'sstrvol', 'cpdist5', 'cpwvol5']
# targets ['move']

# %%
lgb_train.get_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 lgb_train.get_data()
#
# NameError: name 'lgb_train' is not defined

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

params = {
    "boosting_type": "gbdt",
    "objective": "regression",
    "metric": ["rmse", "l1"],
    "num_leaves": 512,
    "learning_rate": 0.19,
    "feature_fraction": 0.9,
    "bagging_fraction": 0.8,
    "bagging_freq": 5,
    "verbose": 1,
    "num_iterations": 1000,
    "num_threads": 24
    #"categorical_feature": "name:descrip_cat,size_cat,sale_cat"
}
'''
model = lgb.LGBMRegressor(**params)
model.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric='mae',
        callbacks=[
            lgb.early_stopping(stopping_rounds=200),
            lgb.log_evaluation(period=50, show_stdv=True)
            ]
        )
'''
gbm = lgb.train(
    params, lgb_train, num_boost_round=20, valid_sets=lgb_eval, callbacks=[
                lgb.early_stopping(stopping_rounds=200),
                lgb.log_evaluation(period=50, show_stdv=True)
            ]
)
# Out:
# d:\applications\miniconda3\envs\torch\Lib\site-packages\lightgbm\engine.py:204: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.059687 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1812
# [LightGBM] [Info] Number of data points in the train set: 5738450, number of used features: 17
# [LightGBM] [Info] Start training from score 1.107767
# Training until validation scores don't improve for 200 rounds
# [50]	valid_0's rmse: 1.61509	valid_0's l1: 0.493008
# [100]	valid_0's rmse: 1.59625	valid_0's l1: 0.485603
# [150]	valid_0's rmse: 1.58556	valid_0's l1: 0.481865
# [200]	valid_0's rmse: 1.58106	valid_0's l1: 0.479156
# [250]	valid_0's rmse: 1.57892	valid_0's l1: 0.477577
# [300]	valid_0's rmse: 1.57361	valid_0's l1: 0.476509
# [350]	valid_0's rmse: 1.57119	valid_0's l1: 0.476109
# [400]	valid_0's rmse: 1.57043	valid_0's l1: 0.475623
# [450]	valid_0's rmse: 1.57055	valid_0's l1: 0.475554
# [500]	valid_0's rmse: 1.57036	valid_0's l1: 0.475428
# [550]	valid_0's rmse: 1.56653	valid_0's l1: 0.475315
# [600]	valid_0's rmse: 1.56662	valid_0's l1: 0.475393
# [650]	valid_0's rmse: 1.5658	valid_0's l1: 0.475246
# [700]	valid_0's rmse: 1.56578	valid_0's l1: 0.475055
# [750]	valid_0's rmse: 1.56649	valid_0's l1: 0.475325
# [800]	valid_0's rmse: 1.56634	valid_0's l1: 0.475471
# [850]	valid_0's rmse: 1.56777	valid_0's l1: 0.475535
# Early stopping, best iteration is:
# [695]	valid_0's rmse: 1.56559	valid_0's l1: 0.475071

# %%
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)

print(f'\n Accuracy: {accuracy_score(y_test, y_pred.astype(int))}')
# Out:
#  Accuracy: 0.7633912420980432

# %%
gbm.save_model('model/02-lightgbm-model.txt', num_iteration=gbm.best_iteration)

# %%
lgb.plot_importance(gbm)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
